# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Read In CSV File**

# %%
cs105_survey = pd.read_csv("Clean data CS105 Winter'26 Mini-Project Survey (Responses) 2.csv")
pd.set_option('display.max_columns', None)
cs105_survey.head()
# Out:
#            Timestamp  \
# 0  2/1/2026 22:54:54
# 1  2/1/2026 23:28:31
# 2  2/1/2026 23:39:26
# 3  2/1/2026 23:44:50
# 4   2/2/2026 0:30:27
#
#   What class are you filling out this survey for? Check all that apply. If none of the listed options apply, select "Other" and enter your class name (for example, CS105).  \
# 0                                              CS105
# 1                                              CS105
# 2                                              CS105
# 3                                              CS111
# 4                                              CS111
#
#   What is your current class standing? Are you a transfer student?  \
# 0                               Senior                         Yes
# 1                               Senior                         Yes
# 2                               Senior                          No
# 3                               Junior                         Yes
# 4                               Senior                          No
#
#   What is your major/minor? (If your major is not listed, please write it in "Other..")  \
# 0                                         CSBA major
# 1                                           CS major
# 2                                     CS or DS minor
# 3                                           CS major
# 4                                           CS major
#
#   What is your current cumulative GPA?  \
# 0                           3.0 – 3.33
# 1                           3.0 – 3.33
# 2                           3.0 – 3.33
# 3                           3.67 – 4.0
# 4                          3.33 – 3.67
#
#    What is your age? Answer with a number only. What is your ethnicity?  \
# 0                                            25                   White
# 1                                            25      Hispanic or Latino
# 2                                            22      Hispanic or Latino
# 3                                            21                   Asian
# 4                                            19                   Asian
#
#   What gender do you identify as? Select ALL that you identify with:  \
# 0                            Male           First Generation Student
# 1                          Female           First Generation Student
# 2                            Male           First Generation Student
# 3                            Male           First Generation Student
# 4                          Female          Second Generation Student
#
#   How many hours of sleep on average do you get? Select a answer for each of the following situations:\r\n [During finals week:]  \
# 0                                          4-5 hours
# 1                                        Less than 4
# 2                                          4-5 hours
# 3                                          4-5 hours
# 4                                          8-9 hours
#
#    Over the past 2 weeks, how often have you felt mentally overwhelmed or stressed\r\n1. Never\r\n2. Almost Never\r\n3. Sometimes\r\n4. Somewhat frequently\r\n5. E5day  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#   Please indicate how much you agree with the following statements regarding the current job market in your major.  (Each row should have one answer) [I feel optimistic about my career prospects in this field]  \
# 0                                              3 (3)
# 1                                              3 (3)
# 2                                       Disagree (2)
# 3                                       Disagree (2)
# 4                                          Agree (4)
#
#    Scale: 1 very poorly, 2 poorly, 3 neutral, 4 well,5 very well  How 4 are you able to concentrate during each of the following:\r\n [In-person lectures]  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  2
#
#    Scale: 1 very poorly, 2 poorly, 3 neutral, 4 well,5 very well How 4 are you able to concentrate during each of the following:\r\n [In-person discussions]  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    Scale: 1 very poorly, 2 poorly, 3 neutral, 4 well,5 very well  How 4 are you able to concentrate during each of the following:\r\n [Online lectures or discussions]  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    Scale: 1 very poorly, 2 poorly, 3 neutral, 4 well,5 very well  How 4 are you able to concentrate during each of the following:\r\n [Small study group sessions]  \
# 0                                                  2
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    Scale: 1 very poorly, 2 poorly, 3 neutral, 4 well,5 very well  How 4 are you able to concentrate during each of the following:\r\n [Exams]  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    How many coding languages would you say you’re proficient in?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                3.0
# 3                                                2.0
# 4                                                4.0
#
#   What was the first programming language you learned?  \
# 0                                              C++/C
# 1                                              C++/C
# 2                                             Python
# 3                                              C++/C
# 4                                               Java
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Final project instead of exam]  \
# 0                                 2 (5 small reason)
# 1                                  5 (5 good reason)
# 2                                  5 (5 good reason)
# 3                                    4 (Good reason)
# 4                                    4 (Good reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Easy exams]  \
# 0                                 2 (5 small reason)
# 1                                    4 (Good reason)
# 2                                3 (Moderate reason)
# 3                                  5 (5 good reason)
# 4                                 2 (5 small reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Friendly professor]  \
# 0                                    4 (Good reason)
# 1                                    4 (Good reason)
# 2                                  5 (5 good reason)
# 3                                    4 (Good reason)
# 4                                    4 (Good reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Accessible office hours]  \
# 0                                    4 (Good reason)
# 1                                3 (Moderate reason)
# 2                              1 (Not a good reason)
# 3                                 2 (5 small reason)
# 4                                 2 (5 small reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Low workload]  \
# 0                                3 (Moderate reason)
# 1                                  5 (5 good reason)
# 2                                 2 (5 small reason)
# 3                                  5 (5 good reason)
# 4                                    4 (Good reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [No required attendence]  \
# 0                                 2 (5 small reason)
# 1                                  5 (5 good reason)
# 2                                 2 (5 small reason)
# 3                                 2 (5 small reason)
# 4                                    4 (Good reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Interested in material]  \
# 0                                  5 (5 good reason)
# 1                                  5 (5 good reason)
# 2                                  5 (5 good reason)
# 3                                    4 (Good reason)
# 4                                  5 (5 good reason)
#
#   Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Prepares for future job]  \
# 0                                  5 (5 good reason)
# 1                                  5 (5 good reason)
# 2                              1 (Not a good reason)
# 3                                  5 (5 good reason)
# 4                                  5 (5 good reason)
#
#   What class(es) do you think prepared you most for the career field you want to pursue? CS courses  \
# 0                                              CS111
# 1                                CS141, CS180, CS100
# 2                                                NaN
# 3                                              CS100
# 4                             CS 100, CS 141, CS010C
#
#   What class(es) do you think prepared you most for the career field you want to pursue? ENGINEERING  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What class(es) do you think prepared you most for the career field you want to pursue? DS courses  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What class(es) do you think prepared you most for the career field you want to pursue? Humanities  \
# 0                                                NaN
# 1                                  ENGR180W, ENGR101
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Think about your time at UCR. Which week during the quarter do you: [Start feeling burnout]  \
# 0                                             Week 5
# 1                                             Week 7
# 2                                             Week 4
# 3                                             Week 7
# 4                                             Week 7
#
#   Think about your time at UCR. Which week during the quarter do you: [Have sleep deprivation]  \
# 0                                             Week 5
# 1                                             Week 4
# 2                                             Week 1
# 3                                             Week 5
# 4                                             Week 4
#
#   Think about your time at UCR. Which week during the quarter do you: [Start feeling less confident in the material]  \
# 0                                             Week 4
# 1                                             Week 6
# 2                                             Week 4
# 3                                             Week 5
# 4                                             Week 3
#
#   Think about your time at UCR. Which week during the quarter do you: [Start feeling more confident in the material]  \
# 0                                             Week 8
# 1                                             Week 9
# 2                                             Week 2
# 3                                             Week 1
# 4                                             Week 8
#
#   Think about your time at UCR. Which week during the quarter do you: [Study the most]  \
# 0                                             Week 8
# 1                                             Week 9
# 2                                             Week 9
# 3                                             Week 8
# 4                                             Week 5
#
#   Think about your time at UCR. Which week during the quarter do you: [Enjoy the most]  \
# 0                                             Week 1
# 1                                             Week 1
# 2                                             Week 2
# 3                                             Week 1
# 4                                             Week 1
#
#   Choose the resources that has been most helpful in your success in your favorite course. Choose all that apply.\r\n  \
# 0          Office hours, AI tools, Personal tutoring
# 1  Office hours, AI tools, Study groups, ULA serv...
# 2                                                NaN
# 3                             AI tools, ULA services
# 4  Office hours, AI tools, Study groups, ULA serv...
#
#    How confidently can you explain the following concepts to someone who hasn’t taken it? \r\n\r\n   FOR CS MAJORS/MINORS: Pointers, if/else statements, for/while loops\r\n   FOR DS MAJORS/MINORS: numpy, pandas, matplotlib, hypothesis testing
# 0                                                3.0
# 1                                                8.0
# 2                                                8.0
# 3                                                8.0
# 4                                               10.0

# %% [markdown]
# **Heat Map**

# %%
favorite_course = cs105_survey.loc[:, 
                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Final project instead of exam]":
                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Prepares for future job]"
            ].copy()

favorite_course = favorite_course.rename(columns={"Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Final project instead of exam]":"Final project instead of exam",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Easy exams]":"Easy exams",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Friendly professor]":"Friendly prof",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Accessible office hours]":"Accessible office hours",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Low workload]":"Low workload",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [No required attendence]":"No required attendence",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Interested in material]":"Interested in material",
                                "Think about your favorite course (4 units). Why was it your favorite course? Rank the following reasons.\r\n [Prepares for future job]":"Prepares for future job"})

favorite_course = favorite_course.apply(pd.Series.value_counts, args=(1, 2)) * 100 

plt.figure(figsize=(10, 8))
plt.title("Why was your favorite course your favorite?")
sns.heatmap(data=favorite_course, center=0, cmap="crest", annot=True, square=True, linewidths=1, cbar_kws={"label":"Percentage"})
plt.show()

# %% [markdown]
# We can see from the data that the features that were most "hot" for answering the question "Why was your favorite course your favorite?" were having a Friendly Prof and being interested in the material. The features that were least correlated were "final project" over exam and "no required attendence".

# %% [markdown]
# **Parallel Coordinate Plot**

# %%
identity_concentration = cs105_survey.iloc[:, 13:18].copy()
identity_concentration["Identity"] = cs105_survey["What gender do you identify as?"]

identity_concentration = identity_concentration.rename(columns={identity_concentration.columns[0]:"In-person lectures",
                                                                identity_concentration.columns[1]:"In-person discussions",
                                                                identity_concentration.columns[2]:"Online lectures or discussions",
                                                                identity_concentration.columns[3]:"Small study group sessions",
                                                                identity_concentration.columns[4]:"Exams"})

identity_concentration_pivot = pd.pivot_table(data=identity_concentration, values=identity_concentration.loc[:, "In-person lectures":"Exams"], index="Identity", aggfunc="mean")
identity_concentration_pivot["Classes"] = identity_concentration_pivot.index

plt.figure(figsize=(12, 8))
pd.plotting.parallel_coordinates(identity_concentration_pivot, "Classes", colormap='viridis', alpha=1.0)
plt.show()
# Out:
# <Axes: >
